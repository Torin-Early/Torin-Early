# %% [markdown]
# <a href="https://colab.research.google.com/github/Torin-Early/Torin-Early/blob/main/tumor_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dataset = pd.read_csv('cancer.csv')

# %%
x = dataset.drop(columns=['diagnosis(1=m, 0=b)'])

# %%
y = dataset['diagnosis(1=m, 0=b)']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
import tensorflow as tf

model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(30, input_shape=x_train.shape[1:], activation='relu'))
model.add(tf.keras.layers.Dense(102, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=210)
# Out:
# Epoch 1/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4424 - loss: 23.6997
# Epoch 2/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5047 - loss: 2.7790
# Epoch 3/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7167 - loss: 1.2871
# Epoch 4/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8414 - loss: 0.5459
# Epoch 5/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8955 - loss: 0.4579
# Epoch 6/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8783 - loss: 0.5473
# Epoch 7/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8660 - loss: 0.4288
# Epoch 8/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8762 - loss: 0.3769
# Epoch 9/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8684 - loss: 0.5064
# Epoch 10/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8925 - loss: 0.3229
# Epoch 11/210
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9215 - loss: 0.2718
# Epoch 12/210
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9244 - loss: 0.1758
# [0.1732911914587021, 0.9385964870452881]
